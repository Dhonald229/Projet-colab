# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhonald229/Projet-colab/blob/main/Etude_d'actif_financier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Projet D'étude d'investissement**

# %%
import pandas as pd

# %%
import yfinance as yf

# %%
prix=yf.Ticker("AAPL").history(period="5y")
prix
# Out:
#                                 Close        High         Low        Open  \
# Date
# 2021-05-07 00:00:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-10 00:00:00-04:00  123.761185  126.385678  123.722158  126.258853
# 2021-05-11 00:00:00-04:00  122.844086  123.195313  119.780538  120.492766
# 2021-05-12 00:00:00-04:00  119.780556  121.605024  119.273221  120.395220
# 2021-05-13 00:00:00-04:00  121.926994  123.078262  121.234284  121.546491
# ...                               ...         ...         ...         ...
# 2026-05-01 00:00:00-04:00  280.140015  287.220001  278.369995  278.859985
# 2026-05-04 00:00:00-04:00  276.829987  280.630005  274.859985  279.660004
# 2026-05-05 00:00:00-04:00  284.179993  284.570007  276.500000  276.929993
# 2026-05-06 00:00:00-04:00  287.510010  288.029999  281.070007  281.920013
# 2026-05-07 00:00:00-04:00  287.440002  292.130005  285.779999  289.269989
#
#                               Volume  Dividends  Stock Splits
# Date
# 2021-05-07 00:00:00-04:00          0       0.22           0.0
# 2021-05-10 00:00:00-04:00   88071200       0.00           0.0
# 2021-05-11 00:00:00-04:00  126142800       0.00           0.0
# 2021-05-12 00:00:00-04:00  112172300       0.00           0.0
# 2021-05-13 00:00:00-04:00  105861300       0.00           0.0
# ...                              ...        ...           ...
# 2026-05-01 00:00:00-04:00   79915400       0.00           0.0
# 2026-05-04 00:00:00-04:00   46668400       0.00           0.0
# 2026-05-05 00:00:00-04:00   49311700       0.00           0.0
# 2026-05-06 00:00:00-04:00   58336100       0.00           0.0
# 2026-05-07 00:00:00-04:00   45145500       0.00           0.0
#
# [1256 rows x 7 columns]

# %%
prix_triés=prix.drop_duplicates().dropna()
prix_triés

# %%
prix_triés.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
incohérences=prix_triés[prix_triés["Low"]>prix_triés["High"]]
incohérences
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Dividends, Stock Splits]
# Index: []

# %%
prix_triés_vn=prix_triés[prix_triés["Volume"]==0]
prix_triés_vn
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Dividends, Stock Splits]
# Index: []

# %% [markdown]
# Calcul du rendement journalier:

# %%
prix_triés["rendement journalier"]=prix_triés["Close"].pct_change()*100
prix_triés
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-05-03 00:00:00-04:00  128.606386  130.583611  128.401855  129.093384
# 2021-05-04 00:00:00-04:00  127.778479  128.070680  123.405233  124.525330
# 2021-05-05 00:00:00-04:00  125.840223  127.057718  124.642213  124.768837
# 2021-05-06 00:00:00-04:00  124.564313  126.375946  123.824074  126.366211
# 2021-05-07 00:00:00-04:00  127.663814  128.063819  126.327163  127.039398
# ...                               ...         ...         ...         ...
# 2026-04-27 00:00:00-04:00  266.089996  268.359985  265.070007  267.609985
# 2026-04-28 00:00:00-04:00  272.339996  273.230011  268.660004  270.709991
# 2026-04-29 00:00:00-04:00  267.549988  271.040009  267.040009  270.170013
# 2026-04-30 00:00:00-04:00  270.500000  276.000000  268.140015  271.350006
# 2026-05-01 00:00:00-04:00  278.859985  287.220001  278.369995  280.140015
#
#                               Volume  Dividends  Stock Splits  rendement  \
# Date
# 2021-05-03 00:00:00-04:00   75135100       0.00           0.0        NaN
# 2021-05-04 00:00:00-04:00  137564700       0.00           0.0  -3.538566
# 2021-05-05 00:00:00-04:00   84000900       0.00           0.0   0.195548
# 2021-05-06 00:00:00-04:00   78128300       0.00           0.0   1.280267
# 2021-05-07 00:00:00-04:00   78973300       0.22           0.0   0.532727
# ...                              ...        ...           ...        ...
# 2026-04-27 00:00:00-04:00   41466800       0.00           0.0  -1.272785
# 2026-04-28 00:00:00-04:00   40018900       0.00           0.0   1.158404
# 2026-04-29 00:00:00-04:00   30047900       0.00           0.0  -0.199467
# 2026-04-30 00:00:00-04:00   91848200       0.00           0.0   0.436759
# 2026-05-01 00:00:00-04:00   79844600       0.00           0.0   3.239362
#
#                            rendement journalier
# Date
# 2021-05-03 00:00:00-04:00                   NaN
# 2021-05-04 00:00:00-04:00             -3.538566
# 2021-05-05 00:00:00-04:00              0.195548
# 2021-05-06 00:00:00-04:00              1.280267
# 2021-05-07 00:00:00-04:00              0.532727
# ...                                         ...
# 2026-04-27 00:00:00-04:00             -1.272785
# 2026-04-28 00:00:00-04:00              1.158404
# 2026-04-29 00:00:00-04:00             -0.199467
# 2026-04-30 00:00:00-04:00              0.436759
# 2026-05-01 00:00:00-04:00              3.239362
#
# [1256 rows x 9 columns]

# %%
pt=prix_triés
rdm_max=round(pt['rendement journalier'].max(), 2)
volume_correspondant=pt[pt['rendement journalier']==pt['rendement journalier'].max()]
print("le rendement journalier maximal est",rdm_max,"%")
# Out:
# le rendement journalier maximal est 15.33 %

# %%
ptdj=pt.tail(90)
ptdj['rendement journalier'].mean()*100
# Out:
# np.float64(3.854358273608162)

# %%
display(pt.tail(100))

# %%
moyenne_rdm=pt["rendement journalier"].mean()*100
moyenne_rdm
# Out:
# np.float64(7.6697668132610985)

# %%
volume_correspondant
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-04-09 00:00:00-04:00  171.203815  199.739448  171.144078  197.987091
#
#                               Volume  Dividends  Stock Splits  rendement  \
# Date
# 2025-04-09 00:00:00-04:00  184395900        0.0           0.0  15.328859
#
#                            rendement journalier
# Date
# 2025-04-09 00:00:00-04:00             15.328859

# %% [markdown]
# **REMARQUE:**
# Après calcul du rendement journalier de l'actif AAPL(Apple), le rendement maximal depuis le 03 Avril 2021 à nos jour est de 15,33% precisement au 09 Mars 2025 avec un volume de **184395900**.Nous obtenons en moyenne sur les **90 derniers jours** un rendement journalier de ***3,85%***.
